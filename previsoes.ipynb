# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r".\data\base_estudantes_tratado.csv")

# %%
sns.lmplot(data=df,x="study_hours_per_day",y="exam_score");

# %%
# X = df[["study_hours_per_day"]]
# y = df["exam_score"]

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(X,y)
# Out:
# LinearRegression()

# %%
novo_aluno = pd.DataFrame({"study_hours_per_day":[0]})
modelo.predict(novo_aluno)
# Out:
# array([35.91016203])

# %%
modelo.coef_
# Out:
# array([ 9.57455765,  1.94891112, -2.61978299, -2.27707733,  0.14472831,
#         2.00461949,  1.45187415])

# %%
modelo.intercept_
# Out:
# np.float64(6.157219266373055)

# %%
modelo.score(X,y)
# Out:
# 0.9010709420532252

# %%
X = df[["study_hours_per_day","mental_health_rating","social_media_hours","netflix_hours","attendance_percentage","sleep_hours", "exercise_frequency"]]
y = df["exam_score"]

# %%
novo_aluno = pd.DataFrame({
    
    "study_hours_per_day":[5],
    "mental_health_rating":[1],
    "social_media_hours":[1],
    "netflix_hours":[2],
    "attendance_percentage":[90],
    "sleep_hours":[8],
    "exercise_frequency":[3]
})
    


modelo.predict(novo_aluno)
# Out:
# array([82.22310763])
