# %%
#Importação de bibliotecas
import numpy as np #np será o apelido

# %%
temperaturas = np.array([30,40,50.60,70,80,90,100])
print(temperaturas)
print(type(temperaturas))
# Out:
# [ 30.   40.   50.6  70.   80.   90.  100. ]
# <class 'numpy.ndarray'>

# %%
#média aritimética
media = np.mean(temperaturas)
print(f"{media:.2f}")
# Out:
# 65.80

# %%
#Retorna o maior valor da lista
maior_valor = np.max(temperaturas)
print(maior_valor)
# Out:
# 100.0

# %%
#Exibir o menor valor
menor_valor = np.max(temperaturas)
print(menor_valor)
# Out:
# 100.0

# %%
#Salários x 1000
salarios = np.array([2,3,4,5,1,500])
media_salarios = np.mean(salarios)
print(media_salarios)
# Out:
# 85.83333333333333

# %%
mediana = np.median(salarios)
print(mediana)
# Out:
# 3.5

# %% [markdown]
# Desafio final:
# - Criar um array de habitantes de 5 cidades do estado de SP.
# - Maior população
# - Menor população
# - Média de população
# - Mediana

# %%
Habitantes = np.array ([247.571,189.456,1187974,64.596,253.474])
maior_valor = np.max(Habitantes)
print(maior_valor)
# Out:
# 1187974.0

# %%
menor_valor = np.min(Habitantes)
print(menor_valor)
# Out:
# 64.596

# %%
mediana_valor = np.median(Habitantes)
print(mediana_valor)
# Out:
# 3.5

# %%
media_valor = np.mean(Habitantes)
print(f"{media_valor:.2f}")
# Out:
# 237745.82
