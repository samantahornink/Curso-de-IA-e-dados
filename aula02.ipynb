# %% [markdown]
# Aula 02 - Introdução ao Python e modelos de dados

# %% [markdown]
# Comparadores lógicos

# %%
print("iniciando Notebook")
# Out:
# iniciando Notebook

# %%
#Comparadores
print(10 > 5) #Se for verdadeiro, retorna True
# Out:
# True

# %%
print (5 <10) #Se for verdadeiro, retorna True
# Out:
# True

# %%
print(10==10) #Realiza comparações de igualdade
# Out:
# True

# %%
print(10!=11) #Compara diferenças
# Out:
# True

# %% [markdown]
# Condicionais

# %%
carga_horaria = 40
if carga_horaria > 40: #Se for maior que 40
    print("Usar uniforme")
else: #Se não
    print("Usar crachá)")
# Out:
# Usar crachá)

# %%
carga_horaria = 60
if carga_horaria > 40: #Se for maior que 40
    print("Usar uniforme")
else: #Se não
    print("Usar crachá")
# Out:
# Usar uniforme

# %%
#Solicitar a informação para o usuário
carga_horaria = int(input("Digite a carga horária do curso"))
if carga_horaria > 40: #Se for maior que 40
    print("Usar uniforme")
else: #Se não
    print("Usar crachá")
# Out:
# Usar crachá

# %% [markdown]
# Programa que avalia as notas que o usuário do nosso aplicativo inseriu.

# %%
avaliacao = float(input("Digite a sua avaliação: 0 - 10 estrelas"))
if avaliacao > 8:
    print("Nota excelente!")
elif avaliacao > 6:
    print("Avaliação regular")
elif avaliacao > 4:
    print("Avaliação ruim")
else:
    print("Avaliação péssima")
# Out:
# Avaliação regular

# %% [markdown]
# Sistema que irá verificar se o filme avaliado é bom ou não.
# - Criar uma variável que irá armazenar o nome do filme.
# - Criar uma variável que irá armazenar a nota do filme (0 - 5)
# - Condição: Se possuir 5 estrelas, filme Vencedor do Oscar.
# - Se possuir de 3 a 4,99, filme Bom para assistir.
# - Abaixo disso, filme não indicado.

# %%
nome_filme = input("Digite o nome do filme")
avaliacao = float(input("Digite a sua avaliação: 0 - 5 estrelas"))
if avaliacao == 5:
    print(f"FILME {nome_filme} VENCEDOR DO OSCAR")
elif avaliacao > 3 and avaliacao <= 4.99:
    print(f"FILME {nome_filme} BOM PARA ASSISTIR")
else:
    print(f"FILME {nome_filme} NÃO INDICADO!")
# Out:
# FILME REI LEAO NÃO INDICADO!

# %%
nome_filme = input("Digite o nome do filme")
avaliacao = float(input("Digite a sua avaliação: 0 - 5 estrelas:"))
if avaliacao <= 0 or avaliacao > 5:
    print("Nota inválida")
else:
    if avaliacao == 5:
        print(f"FILME {nome_filme} VENCEDOR DO OSCAR")
    elif avaliacao >= 3:
        print(f"FILME {nome_filme} BOM PARA ASSISTIR")
    else:
        print(f"FILME {nome_filme} NÃO INDICADO!")
# Out:
# FILME rei leao NÃO INDICADO!

# %% [markdown]
# Estrutura de dados

# %%
#Listas
temperaturas = [30,40,50] #indices
print(temperaturas)
print(temperaturas[0])
print(temperaturas[1])
print(temperaturas[2])
# Out:
# [30, 40, 50]
# 30
# 40
# 50

# %%
#Acesso a posição e realizo a alteração
temperaturas [1] = 45
temperaturas [2] = 35
temperaturas [3] = 55
print(temperaturas)
# Out:
# [30, 45, 50]

# %%
temperaturas.append(60) #Adiciona um valor na lista
print (temperaturas)
# Out:
# [30, 45, 50, 60]
